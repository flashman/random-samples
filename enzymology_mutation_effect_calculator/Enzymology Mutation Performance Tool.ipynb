# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys, os
sys.path.append(os.path.abspath('./code'))
from interface import MutationEffectCalculatorInterface
interface = MutationEffectCalculatorInterface()

# %%
interface.display()

# %%
    results = interface.session.results
    X = results.model.data.exog
    y = results.model.data.endog
    y_pred = results.predict(X)

# %%
results.model.data.ynames

# %%
import emec.utils.statsmodels_utils as su

# %%
su.get_model_predictions_df(interface.session.results)[:5]

# %% [markdown]
# ### Experimental Analyses

# %%
# Set p_threshold to the same value as us used above.
fits_df, coefs_df, counts_df = interface.session.run_generalizability_analysis(p_threshold=0.001)
